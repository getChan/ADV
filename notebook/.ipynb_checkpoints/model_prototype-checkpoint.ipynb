# %%
import pandas as pd
import numpy as np
import warnings

# %%
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_hdf('../data/tokenized_10thousand.hdf')

# %%
df.head()
# Out:
#                                             original  \
# 0  [○, 丙, 申, /, 十, 七, 日, 丙, 申, ,, 太, 祖, 卽, 位, 于, ...
# 1  [○, 上, 在, 潛, 邸, ,, 夢, 有, 神, 人, 執, 金, 尺, 自, 天, ...
# 2  [○, 丁, 酉, /, 雨, 。, 前, 此, 久, 旱, ,, 及, 上, 卽, 位, ...
# 3  [竊, 謂, 小, 邦, ,, 至, 恭, 愍, 王, 薨, 無, 嗣, ,, 逆, 臣, ...
# 4  [○, 立, 義, 興, 親, 軍, 衛, ,, 罷, 都, 摠, 中, 外, 諸, 軍, ...
#
#                                          translation
# 0  [태조/NNP, 가/JKS, 수창/NNP, 궁/NNG, 에서/JKB, 왕위/NNP,...
# 1  [임금/NNG, 이/JKS, 잠/NNG, 저/NNG, 에/JKB, 있/VV, 을/E...
# 2  [비/NNG, 가/JKS, 내리/VV, 었/EP, 다/EF, ./SF, 이/NP, ...
# 3  [도평의사사/NNP, 및/MAJ, 대소/NNG, 신료와/NA, 한량/NNP, ·/S...
# 4  [의/NNG, 흥/NNG, 친군위/NNG, 를/JKO, 설치/NNG, 하/XSV, ...

# %%
import numpy as np

# %% [markdown]
# # Vectorize

# %% [markdown]
# ## id부여
# - 한글의 경우 빈도수 높은 순으로 10000개 아이디를 부여한다. `START`, `OOV`, `PAD`도 아이디 부여해야 한다
# - 한자의 경우 전부 아이디 부여한다. `OOV`, `PAD` 도 아이디 부여해야 한다.

# %%
# from collections import Counter
# input_characters = Counter()
# for line in df.original:
#     input_characters.update(line)

# %%
# input_characters.most_common()

# %%
# len(input_characters)

# %%
# input_id = {ch:id+2 for id, ch in enumerate([_ for _ in zip(*input_characters.most_common())][0])}
# input_id['PAD'] = 0
# input_id['OOV'] = 1
# # out of vector

# %%
# len(input_id)

# %%
# target_characters = Counter()
# for line in df.translation:
#     target_characters.update(line)

# %%
# len(target_characters)

# %%
# target_characters.most_common(10000)
# Out:
# [(',/SP', 1213492),
#  ('하/XSV', 813221),
#  ('./SF', 540212),
#  ('을/JKO', 503400),
#  ('이/JKS', 452220),
#  ('를/JKO', 442281),
#  ('에/JKB', 434008),
#  ('고/EC', 334336),
#  ('의/JKG', 298267),
#  ('"/SS', 295047),
#  ('았/EP', 292713),
#  ('아/EC', 272228),
#  ('다/EF', 238720),
#  ('ㄴ/ETM', 237746),
#  ('하/VV', 237372),
#  ('것/NNB', 233630),
#  ('이/VCP', 223453),
#  ('는/ETM', 219469),
#  ('기/ETN', 211349),
#  ('가/JKS', 208464),
#  ('은/JX', 191295),
#  ('어/EC', 176544),
#  ('는/JX', 170794),
#  ('지/EC', 169387),
#  ('게/EC', 161398),
#  ('ㄹ/ETM', 137806),
#  ('하/XSA', 134744),
#  ('·/SP', 129631),
#  ('었/EP', 129460),
#  ('말/NNG', 95430),
#  ('있/VV', 88046),
#  ('ㅂ니다/EF', 85894),
#  ('없/VA', 83991),
#  ('에서/JKB', 83913),
#  ('그/MM', 82144),
#  ('으로/JKB', 81382),
#  ('니/EC', 78933),
#  ('않/VX', 78266),
#  ('로/JKB', 71920),
#  ('습니다/EF', 70806),
#  ('아서/EC', 70578),
#  ('도/JX', 70537),
#  ('는데/EC', 69221),
#  ('에게/JKB', 68672),
#  ('들/XSN', 68410),
#  ('으니/EC', 68359),
#  ('?/SF', 66725),
#  ('겠/EP', 65262),
#  ('과/JC', 64608),
#  ('등/NNB', 63958),
#  ('수/NNB', 62572),
#  ('사람/NNG', 60569),
#  ('아뢰/VV', 60031),
#  ('되/VV', 58174),
#  ('어서/EC', 56275),
#  ('못하/VX', 54140),
#  ('하/VX', 51780),
#  ('하니/NNP', 50285),
#  ('이/NP', 49506),
#  ('자/NNB', 47868),
#  ('ㅁ/ETN', 46818),
#  ('은/ETM', 46633),
#  ('임금/NNG', 45201),
#  ('시/EP', 44882),
#  ('또/MAJ', 44479),
#  ('면/EC', 44469),
#  ('되/XSV', 42689),
#  ('을/ETM', 42394),
#  ('주/VX', 41725),
#  ('와/JC', 38514),
#  ('일/NNG', 36562),
#  ('모두/MAG', 36293),
#  ('이르/VV', 36264),
#  ('이/MM', 35600),
#  ('명/NNB', 35479),
#  ('한/MM', 33903),
#  ('죄/NNG', 33799),
#  ('1/SN', 33788),
#  ('건대/EC', 33712),
#  ('있/VX', 33145),
#  ('며/EC', 31993),
#  ('ㄴ다/EF', 31734),
#  ('신/NNG', 31125),
#  ('라/EF', 31098),
#  ('때/NNG', 30214),
#  ('알/VV', 29562),
#  ('소서/EF', 29549),
#  ('청하/VV', 29261),
#  ('어찌/MAG', 29171),
#  ('습니까/EF', 28724),
#  ('아니하/VX', 28714),
#  ('의논/NNG', 28373),
#  ('도록/EC', 27915),
#  ('보/VV', 27677),
#  ('아니/VCN', 27668),
#  ('따르/VV', 27495),
#  ('일/NNB', 27292),
#  ('보내/VV', 26605),
#  ('받/VV', 25817),
#  ('ㄴ데/EC', 25185),
#  ('나아가/VV', 24502),
#  ('비록/MAG', 23788),
#  ('으나/EC', 23757),
#  ('오/VV', 23709),
#  ('께서/JKS', 23530),
#  ('가/VV', 22640),
#  ('이미/MAG', 22558),
#  ('내/NP', 22174),
#  ('같/VA', 21852),
#  ('ㄴ/JX', 21785),
#  ('지금/MAG', 21329),
#  ('여러/MM', 20362),
#  ('전하/NNP', 20306),
#  ('생각/NNG', 20289),
#  ('또한/MAJ', 20279),
#  ('반드시/MAG', 19958),
#  ('법/NNG', 18962),
#  ('내리/VV', 18879),
#  ('므로/EC', 18748),
#  ('만/JX', 18643),
#  ('지/VX', 18413),
#  ('다시/MAG', 18250),
#  ('쓰/VV', 18206),
#  ('는가/EF', 18015),
#  ('하여금/MAG', 17955),
#  ('때문/NNB', 17830),
#  ('중/NNB', 17629),
#  ('다고/EC', 17513),
#  ('백/NR', 17481),
#  ('마음/NNG', 17296),
#  ('마땅히/MAG', 17150),
#  ('백성/NNG', 16783),
#  ('으며/EC', 16466),
#  ('만약/MAG', 16338),
#  ('다/MAG', 16056),
#  ('라/EC', 15989),
#  ('전교/NNG', 15882),
#  ('ㄴ다면/EC', 15709),
#  ('으면/EC', 15490),
#  ('년/NNB', 15313),
#  ('으므로/EC', 15269),
#  ('사/NNG', 15148),
#  ('번/NNB', 15140),
#  ('인/NNG', 15126),
#  ('뜻/NNG', 15041),
#  ('그대로/MAG', 14943),
#  ('나라/NNG', 14935),
#  ('김/NNP', 14747),
#  ('우리/NP', 14586),
#  ('이것/NP', 14503),
#  ('예/NNG', 14456),
#  ('데/NNB', 14304),
#  ('3/SN', 14132),
#  ('삼/VV', 14089),
#  ('이제/MAG', 13967),
#  ('2/SN', 13912),
#  ('시키/XSV', 13815),
#  ('말/VX', 13769),
#  ('그러나/MAJ', 13723),
#  ('크/VA', 13571),
#  ('뒤/NNG', 13497),
#  ('더라도/EC', 13448),
#  ('상/NNG', 13425),
#  ('올리/VV', 13177),
#  ('아야/EC', 13095),
#  ('그/NP', 13058),
#  ('다가/EC', 13016),
#  ('길/NNG', 13007),
#  ('많/VA', 12928),
#  ('과/JKB', 12878),
#  ('들/VV', 12854),
#  ('옳/VA', 12655),
#  ('신이/NNP', 12517),
#  ('집/NNG', 12496),
#  ('다만/MAJ', 12468),
#  ('듣/VV', 12365),
#  ('고/JKQ', 12262),
#  ('관/NNG', 12154),
#  ('가지/VV', 12076),
#  ('직/NNG', 11961),
#  ('나/NP', 11934),
#  ('정/NNP', 11934),
#  ('곳/NNG', 11793),
#  ('의/NNG', 11793),
#  ('전/NNG', 11675),
#  ('와/JKB', 11608),
#  ('군사/NNG', 11558),
#  ('행하/VV', 11351),
#  ('위/NNG', 11334),
#  ('두/MM', 11329),
#  ('까지/JX', 11214),
#  ('자/EC', 11112),
#  ('뿐/NNB', 11096),
#  ('여기/VV', 10955),
#  ('면서/EC', 10913),
#  ('같이/MAG', 10860),
#  ('안/NNG', 10835),
#  ('옵/EP', 10832),
#  ('바치/VV', 10769),
#  ('간/NNB', 10647),
#  ('대간/NNP', 10643),
#  ('묻/VV', 10582),
#  ('라고/EC', 10574),
#  ('살/VV', 10366),
#  ('두/VV', 10347),
#  ('서로/MAG', 10176),
#  ('바/NNB', 10080),
#  ('다/EC', 9871),
#  ('지/NNB', 9844),
#  ('던/ETM', 9835),
#  ('윤/NNP', 9800),
#  ('부터/JX', 9698),
#  ('만/NNB', 9687),
#  ('고자/EC', 9589),
#  ('강/NNP', 9534),
#  ('필/NNP', 9488),
#  ('정하/VV', 9388),
#  ('병/NNG', 9320),
#  ('죽/VV', 9216),
#  ('을/NNG', 9210),
#  ('의하/VV', 9094),
#  ('매우/MAG', 9000),
#  ('사신/NNP', 8985),
#  ('수령/NNG', 8964),
#  ('병조/NNP', 8911),
#  ('로써/JKB', 8866),
#  ('예조/NNP', 8834),
#  ('경/NNG', 8681),
#  ('어렵/VA', 8670),
#  ('대답/NNG', 8625),
#  ('진실로/MAG', 8624),
#  ('종/NNG', 8602),
#  ('고을/NNG', 8534),
#  ('만들/VV', 8527),
#  ('대신/NNG', 8474),
#  ('어떻/VA', 8452),
#  ('되/EC', 8442),
#  ('품/NNB', 8433),
#  ('경연/NNP', 8383),
#  ('천/NR', 8365),
#  ('5/SN', 8362),
#  ('사헌부/NNP', 8273),
#  ('각/MM', 8238),
#  ('공/NNG', 8202),
#  ('적/NNB', 8112),
#  ('후/NNG', 8111),
#  ('설치/NNG', 8037),
#  ('부르/VV', 7990),
#  ('일찍이/MAG', 7985),
#  ('나누/VV', 7933),
#  ('려고/EC', 7897),
#  ('곧/MAG', 7890),
#  ('관찰사/NNP', 7885),
#  ('혹은/MAJ', 7884),
#  ('의정부/NNP', 7881),
#  ('나오/VV', 7846),
#  ('잡/VV', 7845),
#  ('절/NNG', 7843),
#  ('각각/MAG', 7729),
#  ('도/NNG', 7707),
#  ('좌/NNG', 7687),
#  ('달/NNG', 7687),
#  ('장/NNP', 7668),
#  ('조정/NNG', 7581),
#  ('인하/VV', 7580),
#  ('판서/NNP', 7575),
#  ('스스로/MAG', 7534),
#  ('성/NNG', 7531),
#  ('4/SN', 7521),
#  ('개/NNB', 7519),
#  ('다스리/VV', 7500),
#  ('만일/NNG', 7441),
#  ('받들/VV', 7417),
#  ('계/NNG', 7394),
#  ('국가/NNG', 7379),
#  ('중국/NNP', 7359),
#  ('다른/MM', 7356),
#  ('다면/EC', 7331),
#  ('군/NNG', 7306),
#  ('얻/VV', 7267),
#  ('자리/NNG', 7172),
#  ('대로/JX', 7160),
#  ('서/NNP', 7142),
#  ('문/NNG', 7112),
#  ('으로서/JKB', 7065),
#  ('고서/EC', 7055),
#  ('입/VV', 7052),
#  ('세우/VV', 7048),
#  ('원/NNB', 7020),
#  ('한/NNP', 7007),
#  ('그렇/VA', 6979),
#  ('당하/VV', 6979),
#  ('감히/MAG', 6974),
#  ('폐단/NNG', 6974),
#  ('고치/VV', 6964),
#  ('시행/NNG', 6849),
#  ('함께/MAG', 6830),
#  ('제수/NNG', 6807),
#  ('바라/VV', 6806),
#  ('박/NNP', 6783),
#  ('어야/EC', 6759),
#  ('좋/VA', 6759),
#  ('처음/NNG', 6725),
#  ('아들/NNG', 6704),
#  ('술/NNG', 6691),
#  ('전지/NNG', 6664),
#  ('부사/NNP', 6657),
#  ('음/ETN', 6638),
#  ('옮기/VV', 6631),
#  ('오/VX', 6626),
#  ('까닭/NNG', 6612),
#  ('제/XPN', 6590),
#  ('거/NNB', 6561),
#  ('마땅/XR', 6530),
#  ('감/NNG', 6519),
#  ('10/SN', 6519),
#  ('지금/NNG', 6493),
#  ('로서/JKB', 6465),
#  ('몸/NNG', 6411),
#  ('돌아오/VV', 6406),
#  ('마다/JX', 6370),
#  ('가하/VV', 6366),
#  ('전/NNP', 6356),
#  ('나/EC', 6323),
#  ('첩/NNG', 6320),
#  ('장차/MAG', 6319),
#  ('하나/NR', 6316),
#  ('더욱/MAG', 6301),
#  ('대하/VV', 6283),
#  ('위하/VV', 6281),
#  ('대/NNB', 6244),
#  ('날/NNG', 6225),
#  ('대/XPN', 6218),
#  ('이조/NNP', 6210),
#  ('먼저/MAG', 6157),
#  ('으시/EP', 6143),
#  ('려/EC', 6083),
#  ('권/NNB', 6028),
#  ('감사/NNG', 6020),
#  ('제사/NNG', 5988),
#  ('신/NNP', 5964),
#  ('앞/NNG', 5961),
#  ('지만/EC', 5937),
#  ('신하/NNG', 5926),
#  ('세/MM', 5924),
#  ('선/NNG', 5920),
#  ('오니/EC', 5890),
#  ('속/NNG', 5863),
#  ('의거/NNG', 5860),
#  ('형조/NNP', 5837),
#  ('돌아가/VV', 5833),
#  ('아울러/MAG', 5829),
#  ('추/NNG', 5821),
#  ('씨/NNB', 5819),
#  ('작/VA', 5783),
#  ('가지/NNB', 5768),
#  ('으로써/JKB', 5739),
#  ('복/NNG', 5735),
#  ('보다/JKB', 5724),
#  ('전/MM', 5685),
#  ('더불/VV', 5681),
#  ('거두/VV', 5680),
#  ('승정원/NNP', 5680),
#  ('들어가/VV', 5649),
#  ('거느리/VV', 5647),
#  ('해/NNG', 5635),
#  ('국문/NNG', 5625),
#  ('갖추/VV', 5591),
#  ('만/NR', 5580),
#  ('형/NNG', 5569),
#  ('이/NNP', 5563),
#  ('손/NNG', 5562),
#  ('대부/NNP', 5515),
#  ('성상/NNG', 5514),
#  ('인도/NNG', 5486),
#  ('적/VA', 5450),
#  ('사오/EP', 5433),
#  ('물건/NNG', 5409),
#  ('함/NNG', 5382),
#  ('배/NNG', 5381),
#  ('일어나/VV', 5376),
#  ('마치/VV', 5367),
#  ('땅/NNG', 5360),
#  ('척/NNB', 5350),
#  ('승지/NNG', 5344),
#  ('염려/NNG', 5321),
#  ('기다리/VV', 5290),
#  ('물/NNG', 5279),
#  ('ㄴ가/EF', 5276),
#  ('이상/NNG', 5264),
#  ('베풀/VV', 5253),
#  ('참/NNG', 5251),
#  ('견/NNG', 5251),
#  ('놓/VX', 5246),
#  ('벼슬/NNG', 5240),
#  ('바로/MAG', 5194),
#  ('평안도/NNP', 5189),
#  ('불가/NNG', 5185),
#  ('호/NNB', 5174),
#  ('홍/NNP', 5170),
#  ('심하/VA', 5152),
#  ('오히려/MAJ', 5150),
#  ('밖/NNG', 5144),
#  ('다는/ETM', 5137),
#  ('세/NNB', 5122),
#  ('무리/NNG', 5113),
#  ('글/NNG', 5110),
#  ('궁/NNG', 5099),
#  ('저/NP', 5085),
#  ('역/NNG', 5083),
#  ('더하/VV', 5081),
#  ('잘/MAG', 5068),
#  ('바가/NNP', 5057),
#  ('금/NNG', 5044),
#  ('살피/VV', 5039),
#  ('영/NNP', 5007),
#  ('지나/VV', 4993),
#  ('논/NNG', 4944),
#  ('비/NNG', 4904),
#  ('그것/NP', 4891),
#  ('언/NNG', 4888),
#  ('이나/JC', 4883),
#  ('원하/VV', 4875),
#  ('하늘/NNG', 4863),
#  ('6/SN', 4855),
#  ('거나/EC', 4853),
#  ('덕/NNG', 4833),
#  ('문/NNP', 4831),
#  ('논하/VV', 4818),
#  ('허락/NNG', 4818),
#  ('죽이/VV', 4816),
#  ('관원/NNG', 4809),
#  ('의금부/NNP', 4776),
#  ('명령/NNG', 4761),
#  ('역시/MAJ', 4747),
#  ('어떠/XR', 4747),
#  ('ㄴ다고/EC', 4730),
#  ('아도/EC', 4727),
#  ('무릇/NNP', 4720),
#  ('친히/MAG', 4707),
#  ('스럽/XSA', 4703),
#  ('조/NNP', 4700),
#  ('버리/VX', 4682),
#  ('적/XSN', 4671),
#  ('엎드리/VV', 4623),
#  ('옵니다/EF', 4602),
#  ('용서/NNG', 4581),
#  ('정사/NNG', 4569),
#  ('포/NNG', 4568),
#  ('들어오/VV', 4566),
#  ('제도/NNG', 4548),
#  ('하물며/MAJ', 4543),
#  ('능히/MAG', 4542),
#  ('경/NNP', 4531),
#  ('ㄹ/JKO', 4513),
#  ('효/NNG', 4511),
#  ('차/VV', 4503),
#  ('은혜/NNG', 4493),
#  ('특별히/MAG', 4491),
#  ('대군/NNP', 4485),
#  ('치/VV', 4469),
#  ('ㄹ까/EC', 4466),
#  ('봉/NNG', 4463),
#  ('나가/VV', 4456),
#  ('왕/NNG', 4450),
#  ('아직/MAG', 4450),
#  ('느냐/EF', 4450),
#  ('범하/VV', 4446),
#  ('고하/VV', 4446),
#  ('매/EC', 4384),
#  ('서/VV', 4377),
#  ('질/XSN', 4370),
#  ('이러/XR', 4370),
#  ('더니/EC', 4369),
#  ('삼가/MAG', 4356),
#  ('너희/NP', 4337),
#  ('부/NNG', 4333),
#  ('미치/VV', 4318),
#  ('옛날/NNG', 4293),
#  ('요/EC', 4292),
#  ('많이/MAG', 4279),
#  ('가운데/NNG', 4266),
#  ('석/NNB', 4254),
#  ('두려워하/VV', 4249),
#  ('용/XSN', 4236),
#  ('쌓/VV', 4236),
#  ('전하/VV', 4226),
#  ('야인/NNG', 4209),
#  ('혹/MAG', 4205),
#  ('제/XSN', 4202),
#  ('부/XPN', 4183),
#  ('이하/NNG', 4178),
#  ('라도/EC', 4177),
#  ('는다/EF', 4163),
#  ('계/XSN', 4156),
#  ('보이/VV', 4151),
#  ('책/NNG', 4143),
#  ('시키/VV', 4137),
#  ('드리/VV', 4118),
#  ('및/MAJ', 4111),
#  ('나이/NNG', 4106),
#  ('오래/MAG', 4095),
#  ('관계/NNG', 4090),
#  ('부/NNB', 4090),
#  ('국/NNG', 4073),
#  ('상고/NNG', 4062),
#  ('무슨/MM', 4057),
#  ('무엇/NP', 4057),
#  ('씩/XSN', 4043),
#  ('율/NNG', 4038),
#  ('소/NNP', 4025),
#  ('듯/NNB', 4006),
#  ('진/NNP', 4000),
#  ('처/NNG', 3995),
#  ('다음/NNG', 3985),
#  ('송/NNP', 3972),
#  ('지키/VV', 3964),
#  ('윤허/NNG', 3959),
#  ('입/NNG', 3954),
#  ('세자/NNG', 3952),
#  ('실로/MAG', 3937),
#  ('모든/MM', 3933),
#  ('차/NNG', 3917),
#  ('타/VV', 3916),
#  ('지내/VV', 3911),
#  ('헌/MM', 3889),
#  ('남/NNP', 3878),
#  ('우/NNP', 3872),
#  ('만나/VV', 3872),
#  ('없이/MAG', 3869),
#  ('귀/NNG', 3860),
#  ('이제/NNG', 3860),
#  ('내/VV', 3841),
#  ('잘못/NNG', 3833),
#  ('생/XSN', 3825),
#  ('더/MAG', 3816),
#  ('창/NNG', 3812),
#  ('사간원/NNP', 3810),
#  ('공신/NNP', 3805),
#  ('20/SN', 3800),
#  ('성/XSN', 3800),
#  ('이름/NNG', 3798),
#  ('그치/VV', 3788),
#  ('들어주/VV', 3776),
#  ('맡/VV', 3773),
#  ('승/NNG', 3764),
#  ('사오니/EC', 3755),
#  ('일/NNP', 3749),
#  ('참판/NNP', 3738),
#  ('제사/NNP', 3734),
#  ('좌우/NNG', 3723),
#  ('노비/NNP', 3715),
#  ('자기/NP', 3711),
#  ('서/JKB', 3709),
#  ('ㅂ니까/EF', 3703),
#  ('기록/NNG', 3697),
#  ('고/MM', 3697),
#  ('서울/NNP', 3692),
#  ('강하/VA', 3691),
#  ('취하/VV', 3684),
#  ('ㄴ다는/ETM', 3667),
#  ('방/NNG', 3643),
#  ('도의/NNP', 3639),
#  ('임명/NNG', 3639),
#  ('8/SN', 3627),
#  ('멀/VA', 3626),
#  ('사실/NNG', 3614),
#  ('7/SN', 3606),
#  ('다르/VA', 3600),
#  ('겸/NNB', 3592),
#  ('밝/VA', 3585),
#  ('합/NNG', 3574),
#  ('향/NNG', 3568),
#  ('조/NR', 3566),
#  ('유/NNP', 3563),
#  ('목/NNG', 3561),
#  ('정지/NNG', 3534),
#  ('관리/NNG', 3534),
#  ('잃/VV', 3532),
#  ('그대/NP', 3524),
#  ('관이/NNP', 3521),
#  ('도망/NNG', 3519),
#  ('동안/NNG', 3510),
#  ('건/NNB', 3509),
#  ('재상/NNP', 3509),
#  ('본래/NNG', 3499),
#  ('그리고/MAJ', 3495),
#  ('석/MM', 3478),
#  ('나/JC', 3464),
#  ('금하/VV', 3460),
#  ('대사헌/NNP', 3448),
#  ('아래/NNG', 3448),
#  ('의심/NNG', 3447),
#  ('맞/VV', 3444),
#  ('먹/VV', 3429),
#  ('헤아리/VV', 3428),
#  ('나/VV', 3426),
#  ('라고/NNP', 3422),
#  ('사이/NNG', 3411),
#  ('두렵/VA', 3405),
#  ('미/NNP', 3396),
#  ('힘쓰/VV', 3393),
#  ('꿇어앉/VV', 3393),
#  ('경상도/NNP', 3389),
#  ('한명회/NNP', 3388),
#  ('신/XPN', 3379),
#  ('절도사/NNP', 3379),
#  ('아비/NNP', 3363),
#  ('해당/NNG', 3332),
#  ('누구/NP', 3331),
#  ('하기/NNP', 3326),
#  ('첨/NNG', 3324),
#  ('즉시/MAG', 3324),
#  ('악/NNG', 3320),
#  ('바꾸/VV', 3313),
#  ('경계/NNG', 3303),
#  ('전지/NNP', 3300),
#  ('교/NNG', 3297),
#  ('사사/NNP', 3280),
#  ('가볍/VA', 3276),
#  ('산/NNG', 3272),
#  ('서/NNG', 3268),
#  ('마침내/MAG', 3261),
#  ('백성/NNP', 3255),
#  ('재/XPN', 3250),
#  ('최/NNP', 3236),
#  ('임/NNP', 3233),
#  ('구하/VV', 3198),
#  ('로부터/JKB', 3192),
#  ('파/NNG', 3191),
#  ('아내/NNG', 3184),
#  ('50/SN', 3184),
#  ('상/XSN', 3183),
#  ('칙/NNG', 3183),
#  ('윤필상/NNP', 3182),
#  ('막/VV', 3180),
#  ('제조/NNG', 3180),
#  ('체/NNG', 3172),
#  ('갑자기/MAG', 3163),
#  ('모르/VV', 3161),
#  ('충/NNG', 3159),
#  ('시험/NNG', 3153),
#  ('여기/NP', 3149),
#  ('주/NNG', 3144),
#  ('도/NNB', 3144),
#  ('야/JX', 3141),
#  ('녹/NNG', 3137),
#  ('중추원/NNP', 3132),
#  ('상소/NNG', 3131),
#  ('호군/NNP', 3124),
#  ('쌀/NNG', 3119),
#  ('은/NNP', 3105),
#  ('외방/NNG', 3101),
#  ('여/XSN', 3100),
#  ('징계/NNG', 3097),
#  ('하사/NNG', 3094),
#  ('라는/ETM', 3089),
#  ('차례/NNG', 3076),
#  ('찬/NNG', 3074),
#  ('뽑/VV', 3070),
#  ('하/NNG', 3065),
#  ('조종/NNG', 3063),
#  ('오르/VV', 3055),
#  ('태종/NNP', 3052),
#  ('어도/EC', 3045),
#  ('심히/MAG', 3039),
#  ('근/NNB', 3039),
#  ('높/VA', 3033),
#  ('사용/NNG', 3028),
#  ('지마는/EC', 3016),
#  ('ㄴ다/EC', 3013),
#  ('항상/MAG', 3012),
#  ('변방/NNG', 3010),
#  ('시/NNB', 3004),
#  ('이루/VV', 3003),
#  ('믿/VV', 2996),
#  ('머무르/VV', 2994),
#  ('드디어/MAG', 2989),
#  ('전라도/NNP', 2988),
#  ('핵/NNG', 2982),
#  ('량/NNB', 2975),
#  ('처하/VV', 2963),
#  ('역사/NNG', 2954),
#  ('금년/NNG', 2953),
#  ('간사/XR', 2945),
#  ('망/NNG', 2944),
#  ('실/NNG', 2940),
#  ('정부/NNG', 2935),
#  ('광/NNG', 2927),
#  ('임금/NNP', 2920),
#  ('도리어/MAG', 2918),
#  ('30/SN', 2910),
#  ('는다면/EC', 2900),
#  ('황/NNP', 2899),
#  ('각기/MAG', 2896),
#  ('거든/EC', 2895),
#  ('아름답/VA', 2883),
#  ('오직/MAG', 2880),
#  ('지/NNG', 2874),
#  ('납/NNG', 2867),
#  ('거의/MAG', 2857),
#  ('조금/MAG', 2857),
#  ('매/MM', 2856),
#  ('도승지/NNP', 2853),
#  ('일으키/VV', 2852),
#  ('곡식/NNG', 2835),
#  ('나머지/NNG', 2822),
#  ('그런데/MAJ', 2814),
#  ('총/NNG', 2809),
#  ('오/EP', 2804),
#  ('민/NNP', 2804),
#  ('육조/NNP', 2784),
#  ('종친/NNG', 2782),
#  ('무/XPN', 2777),
#  ('장령/NNG', 2774),
#  ('행/NNB', 2773),
#  ('적당/XR', 2763),
#  ('대저/MAG', 2761),
#  ('통하/VV', 2758),
#  ('허물/NNG', 2755),
#  ('양/NNP', 2752),
#  ('처럼/JKB', 2752),
#  ('현/NNP', 2742),
#  ('청/NNG', 2728),
#  ('동/NNG', 2726),
#  ('줄/NNB', 2715),
#  ('오로지/MAG', 2712),
#  ('상왕/NNP', 2706),
#  ('지방/NNG', 2702),
#  ('변/NNP', 2695),
#  ('흥/NNG', 2691),
#  ('초/XPN', 2687),
#  ('사직/NNP', 2684),
#  ('청/NNP', 2682),
#  ('계책/NNG', 2679),
#  ('려는/ETM', 2679),
#  ('가리/VV', 2678),
#  ('옛/MM', 2669),
#  ('신숙주/NNP', 2667),
#  ('았었/EP', 2662),
#  ('외/NNB', 2659),
#  ('화/NNG', 2656),
#  ('도절/NNP', 2653),
#  ('나타나/VV', 2651),
#  ('유사/NNP', 2650),
#  ('헌/NNP', 2648),
#  ('자손/NNG', 2645),
#  ('재주/NNG', 2628),
#  ('활/NNG', 2627),
#  ('세조/NNP', 2627),
#  ('으면서/EC', 2625),
#  ('그러/XR', 2623),
#  ('따라서/MAJ', 2621),
#  ('좋아하/VV', 2621),
#  ('지극/XR', 2616),
#  ('대비/NNG', 2611),
#  ('자세히/MAG', 2605),
#  ('지평/NNP', 2598),
#  ('저/MM', 2595),
#  ('대개/MAG', 2592),
#  ('노사신/NNP', 2587),
#  ('충청도/NNP', 2580),
#  ('대전/NNP', 2580),
#  ('가깝/VA', 2578),
#  ('권/NNP', 2571),
#  ('왕세자/NNP', 2560),
#  ('맹/XR', 2552),
#  ('좇/VV', 2547),
#  ('노/NNP', 2545),
#  ('이런/MM', 2541),
#  ('없애/VV', 2536),
#  ('호조/NNP', 2532),
#  ('반/NNG', 2532),
#  ('보고/NNG', 2530),
#  ('열/VV', 2529),
#  ('조사/NNG', 2528),
#  ('쏘/VV', 2527),
#  ('통례/NNG', 2517),
#  ('주/NNP', 2516),
#  ('분/NNB', 2509),
#  ('힘/NNG', 2502),
#  ('일컫/VV', 2490),
#  ('!/SF', 2487),
#  ('ㄹ지라도/EC', 2477),
#  ('형/XSN', 2473),
#  ('더구나/MAJ', 2466),
#  ('도적/NNG', 2457),
#  ('북/NNP', 2453),
#  ('짓/VV', 2451),
#  ('주강/NNP', 2448),
#  ('부모/NNG', 2444),
#  ('면/NNG', 2442),
#  ('9/SN', 2441),
#  ('앉/VV', 2432),
#  ('근심/NNG', 2426),
#  ('이렇/VA', 2425),
#  ('과연/MAG', 2423),
#  ('구/XPN', 2423),
#  ('정승/NNP', 2415),
#  ('앞서/MAG', 2408),
#  ('랑/JKB', 2406),
#  ('사가/NNP', 2403),
#  ('어/NNG', 2397),
#  ('곡/NNG', 2394),
#  ('영의정/NNP', 2390),
#  ('내/NNB', 2388),
#  ('졸/NNG', 2386),
#  ('가두/VV', 2382),
#  ('지극히/MAG', 2381),
#  ('이때/NNG', 2381),
#  ('평/NNB', 2381),
#  ('환/NNG', 2380),
#  ('엄하/VA', 2371),
#  ('요동/NNP', 2363),
#  ('모이/VV', 2362),
#  ('예전/NNG', 2355),
#  ('호조/NNG', 2355),
#  ('의식/NNG', 2351),
#  ('그러므로/MAJ', 2343),
#  ('혹시/MAG', 2342),
#  ('정성/NNG', 2340),
#  ('선왕/NNG', 2339),
#  ('올/MM', 2338),
#  ('마시/VV', 2323),
#  ('황해도/NNP', 2320),
#  ('위로/NNG', 2303),
#  ('근/MM', 2302),
#  ('왜인/NNP', 2300),
#  ('풍속/NNG', 2298),
#  ('화/XSN', 2291),
#  ('고/XPN', 2287),
#  ('치/NNG', 2287),
#  ('극/NNG', 2269),
#  ('면하/VV', 2269),
#  ('고신/NNG', 2268),
#  ('도로/MAG', 2264),
#  ('도리/NNG', 2262),
#  ('사정/NNG', 2260),
#  ('은데/EC', 2259),
#  ('과/NNG', 2251),
#  ('롭/XSA', 2249),
#  ('네/MM', 2244),
#  ('의주/NNP', 2243),
#  ('이기/VV', 2242),
#  ('도둑/NNG', 2239),
#  ('편하/VA', 2236),
#  ('백관/NNG', 2235),
#  ('어미/NNG', 2234),
#  ('장/NNG', 2223),
#  ('흉년/NNG', 2219),
#  ('맡기/VV', 2218),
#  ('둥/NNB', 2217),
#  ('옥/NNG', 2215),
#  ('황제/NNP', 2214),
#  ('참의/NNP', 2214),
#  ('보/NNG', 2213),
#  ('직책/NNG', 2212),
#  ('쇄/NNG', 2211),
#  ('방어/NNG', 2210),
#  ('사랑/NNG', 2210),
#  ('참여/NNG', 2209),
#  ('보니/NNP', 2208),
#  ('문안/NNG', 2206),
#  ('어긋나/VV', 2201),
#  ('리/NNP', 2199),
#  ('지나치/VA', 2194),
#  ('점/NNB', 2193),
#  ('사신/NNG', 2188),
#  ('너/NP', 2186),
#  ('북향/NNG', 2185),
#  ('초/NNB', 2184),
#  ('끝/NNG', 2184),
#  ('말씀/NNG', 2183),
#  ('아/NNP', 2180),
#  ('편안/NNG', 2175),
#  ('작/NNG', 2170),
#  ('도다/EF', 2170),
#  ('기/NNG', 2169),
#  ('홍문관/NNP', 2169),
#  ('빼앗/VV', 2168),
#  ('정창손/NNP', 2165),
#  ('표/NNG', 2161),
#  ('종묘/NNP', 2153),
#  ('시/NNG', 2145),
#  ('본국/NNG', 2143),
#  ('조금/NNG', 2135),
#  ('군/NNB', 2134),
#  ('밝히/VV', 2133),
#  ('대로/NNB', 2133),
#  ('처리/NNG', 2132),
#  ('잔치/NNG', 2130),
#  ('면포/NNG', 2129),
#  ('깊이/MAG', 2126),
#  ('명하/VV', 2126),
#  ('공/NNP', 2125),
#  ('함부로/MAG', 2124),
#  ('규/NNG', 2113),
#  ('어기/VV', 2107),
#  ('랑/NNP', 2099),
#  ('을까/EC', 2096),
#  ('형세/NNG', 2095),
#  ('왕래/NNG', 2086),
#  ('판/NNG', 2086),
#  ('이극배/NNP', 2084),
#  ('참으로/MAG', 2079),
#  ('사관/NNP', 2078),
#  ('멀리/MAG', 2066),
#  ('품/VV', 2066),
#  ('이익/NNG', 2065),
#  ('살펴보/VV', 2064),
#  ('태조/NNP', 2059),
#  ('너무/MAG', 2055),
#  ('정사/NNP', 2053),
#  ('옷/NNG', 2050),
#  ('밤/NNG', 2045),
#  ('몰래/MAG', 2042),
#  ('강원도/NNP', 2042),
#  ('변경/NNG', 2042),
#  ('숨기/VV', 2038),
#  ('정문/NNP', 2036),
#  ('잔/NNG', 2034),
#  ('토/NNG', 2032),
#  ('부원군/NNP', 2026),
#  ('경/XSN', 2025),
#  ('지경/NNB', 2024),
#  ('당/NNG', 2024),
#  ('부득이/MAG', 2022),
#  ('다투/VV', 2021),
#  ('그르/VA', 2021),
#  ('거짓/NNG', 2015),
#  ('몇/MM', 2009),
#  ('단지/MAG', 2004),
#  ('거행/NNG', 1999),
#  ('원망/NNG', 1996),
#  ('무/NNG', 1995),
#  ('응/NNP', 1995),
#  ('증/NNG', 1995),
#  ('이번/NNG', 1990),
#  ('관사/NNP', 1989),
#  ('돌려보내/VV', 1987),
#  ('정언/NNG', 1985),
#  ('홍응/NNP', 1984),
#  ('사직/NNG', 1974),
#  ('모름지기/MAG', 1972),
#  ('황제/NNG', 1971),
#  ('전일/NNG', 1967),
#  ('빨리/MAG', 1966),
#  ('태/NNP', 1959),
#  ('하지/NNP', 1959),
#  ('포/NNP', 1957),
#  ('검/NNG', 1956),
#  ('섬기/VV', 1953),
#  ('로이/NNP', 1951),
#  ('석/NNP', 1946),
#  ('감찰/NNG', 1939),
#  ('품/NNG', 1937),
#  ('소/XPN', 1937),
#  ('주상/NNP', 1937),
#  ('농사/NNG', 1934),
#  ('결단/NNG', 1932),
#  ('파직/NNG', 1930),
#  ('서쪽/NNG', 1929),
#  ('안/NNP', 1925),
#  ('연/NNG', 1925),
#  ('회/NNB', 1921),
#  ('알리/VV', 1919),
#  ('세상/NNG', 1915),
#  ('형벌/NNP', 1914),
#  ('관직/NNG', 1910),
#  ('채/NNB', 1910),
#  ('금지/NNG', 1908),
#  ('사냥/NNG', 1904),
#  ('왕이/NNP', 1897),
#  ('우의정/NNP', 1897),
#  ('각도/NNP', 1895),
#  ('깊/VA', 1886),
#  ('이나/JX', 1885),
#  ('바야흐로/MAG', 1882),
#  ('모시/VV', 1880),
#  ('피/NNG', 1877),
#  ('향하/VV', 1876),
#  ('리/NNB', 1872),
#  ('패/NNG', 1871),
#  ('유시/NNP', 1871),
#  ('소속/NNG', 1869),
#  ('하교/NNG', 1866),
#  ('기르/VV', 1863),
#  ('추/NNP', 1863),
#  ('이유/NNG', 1859),
#  ('늙/VV', 1859),
#  ('오늘/NNG', 1857),
#  ('죄수/NNG', 1854),
#  ('득/NNG', 1849),
#  ('범/NNG', 1845),
#  ('합당/XR', 1844),
#  ('발/NNG', 1840),
#  ('합하/VV', 1840),
#  ('저/XPN', 1831),
#  ('15/SN', 1829),
#  ('딸/NNG', 1829),
#  ...]

# %%
# target_id = {ch:id+3 for id, ch in enumerate([_ for _ in zip(*target_characters.most_common(10000))][0])}
# target_id['PAD'] = 0
# target_id['OOV'] = 1
# target_id['START'] = 2 # start character의 id를 0으로 설정하자

# %%
# len(target_id)
# Out:
# 10003

# %%
# # 단어 사전을 json 파일로 저장
# import json
# with open('./id_dict/input_id.json', 'w') as fp:
#     json.dump(input_id, fp)

# with open('./id_dict/target_id.json', 'w') as fp:    
#     json.dump(target_id, fp)

# %%
# json으로 저장한 단어 사전 불러오기
import json

with open('./id_dict/input_id.json', 'r') as fp:
    input_id = json.load(fp)

with open('./id_dict/target_id.json', 'r') as fp:
    target_id = json.load(fp)

# %%
# 데이터셋을 아이디값으로 변환(vectorize)
original = df.original.apply(lambda y :np.array(list(map(lambda x:input_id[x], y)))).to_numpy()
# 한글의 경우 20000개 안에 없는 단어가 있을 수 있다.
# OOV 아이디인 1로 바꿔줘야 한다.
translation = df.translation.apply(lambda y :np.array(list(map(lambda x:target_id.setdefault(x, 1), y)))).to_numpy()

# %% [markdown]
# # Padding
# 최대 문장의 길이(== 모델 인풋)를 `200`으로 설정해서 문장 길이가 `200`이 되지 않으면 padding 한다
#
# `200`넘으면 잘라버린다.
#
# padding의 id는 `0`으로 부여한다.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
encoder_input_data = pad_sequences(original, maxlen=200, padding='post', truncating='post')
decoder_target_data = pad_sequences(translation, maxlen=200, padding='post', truncating='post')

# %%
encoder_input_data
# Out:
# array([[ 11, 516, 202, ..., 713, 604, 426],
#        [ 11,  14, 117, ..., 178,  24,   3],
#        [ 11, 345, 613, ...,   0,   0,   0],
#        ...,
#        [ 11, 391,  44, ...,   0,   0,   0],
#        [ 11, 510,  43, ...,   0,   0,   0],
#        [ 11, 413, 590, ...,   0,   0,   0]])

# %%
# decoder input data는 <start> character (== 2)로 시작해야 하며 1 time 씩 밀어내야 한다.
tmp = []
for t in translation:
    a = [2]
    a.extend(list(t))
    tmp.append(a)
tmp = np.array(tmp)

decoder_input_data = pad_sequences(tmp, maxlen=200, padding='post', truncating='post')

# %%
decoder_input_data
# Out:
# array([[   2,  913,   22, ...,   88,   26,   58],
#        [   2,   65,    7, ...,   15,    5, 1647],
#        [   2,  421,   22, ...,    0,    0,    0],
#        ...,
#        [   2,  717,    1, ...,    0,    0,    0],
#        [   2, 2362,  416, ...,    0,    0,    0],
#        [   2,  139,    4, ...,    0,    0,    0]])

# %%
encoder_input_data.shape, decoder_target_data.shape, decoder_input_data.shape
# Out:
# ((99996, 200), (99996, 200), (99996, 200))

# %%
batch_size = 1  # Batch size for training.
epochs = 1  # Number of epochs to train for.
latent_dim = 256  # 인코더 차원
num_encoder_tokens = 7049 # unique한 한자 캐릭터의 수
num_decoder_tokens = 10003 # unique한 한글 토큰의 수
embedding_dim = 256 # 워드 임베딩 길이

# %%
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Softmax
from tensorflow.keras.models import Model

# %%
# Define an input sequence and process it.
encoder_input = Input(shape=(None,))
encoder_embedding = Embedding(num_encoder_tokens, embedding_dim)(encoder_input)
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_embedding)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_input = Input(shape=(None,))
decoder_embedding = Embedding(num_decoder_tokens, embedding_dim)(decoder_input)
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_input, decoder_input], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# Train on 79996 samples, validate on 20000 samples
#   359/79996 [..............................] - ETA: 49:09:41 - loss: 2.7792 - accuracy: 0.6098
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-e1229058f275> in <module>
#      29           batch_size=batch_size,
#      30           epochs=epochs,
# ---> 31           validation_split=0.2)
#      32 # Save model
#      33 model.save('s2s.h5')
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# # Next: inference mode (sampling).
# # Here's the drill:
# # 1) encode input and retrieve initial decoder state
# # 2) run one step of decoder with this initial state
# # and a "start of sequence" token as target.
# # Output will be the next target token
# # 3) Repeat with the current target token and current states

# # Define sampling models
# encoder_model = Model(encoder_inputs, encoder_states)

# decoder_state_input_h = Input(shape=(latent_dim,))
# decoder_state_input_c = Input(shape=(latent_dim,))
# decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
# decoder_outputs, state_h, state_c = decoder_lstm(
#     decoder_inputs, initial_state=decoder_states_inputs)
# decoder_states = [state_h, state_c]
# decoder_outputs = decoder_dense(decoder_outputs)
# decoder_model = Model(
#     [decoder_inputs] + decoder_states_inputs,
#     [decoder_outputs] + decoder_states)

# # Reverse-lookup token index to decode sequences back to
# # something readable.
# reverse_input_char_index = dict(
#     (i, char) for char, i in input_token_index.items())
# reverse_target_char_index = dict(
#     (i, char) for char, i in target_token_index.items())


# def decode_sequence(input_seq):
#     # Encode the input as state vectors.
#     states_value = encoder_model.predict(input_seq)

#     # Generate empty target sequence of length 1.
#     target_seq = np.zeros((1, 1, num_decoder_tokens))
#     # Populate the first character of target sequence with the start character.
#     target_seq[0, 0, target_token_index['\t']] = 1.

#     # Sampling loop for a batch of sequences
#     # (to simplify, here we assume a batch of size 1).
#     stop_condition = False
#     decoded_sentence = ''
#     while not stop_condition:
#         output_tokens, h, c = decoder_model.predict(
#             [target_seq] + states_value)

#         # Sample a token
#         sampled_token_index = np.argmax(output_tokens[0, -1, :])
#         sampled_char = reverse_target_char_index[sampled_token_index]
#         decoded_sentence += sampled_char

#         # Exit condition: either hit max length
#         # or find stop character.
#         if (sampled_char == '\n' or
#            len(decoded_sentence) > max_decoder_seq_length):
#             stop_condition = True

#         # Update the target sequence (of length 1).
#         target_seq = np.zeros((1, 1, num_decoder_tokens))
#         target_seq[0, 0, sampled_token_index] = 1.

#         # Update states
#         states_value = [h, c]

#     return decoded_sentence


# for seq_index in range(100):
#     # Take one sequence (part of the training set)
#     # for trying out decoding.
#     input_seq = encoder_input_data[seq_index: seq_index + 1]
#     decoded_sentence = decode_sequence(input_seq)
#     print('-')
#     print('Input sentence:', input_texts[seq_index])
#     print('Decoded sentence:', decoded_sentence)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-108-03d12f3fa006> in <module>
#       1 # Define an input sequence and process it.
# ----> 2 encoder_inputs = Input(shape=(None))
#       3 encoder = LSTM(latent_dim, return_state=True)
#       4 encoder_outputs, state_h, state_c = encoder(encoder_inputs)
#       5 # We discard `encoder_outputs` and only keep the states.
#
# ~\Anaconda3\envs\advpjt\lib\site-packages\keras\engine\input_layer.py in Input(shape, batch_shape, name, dtype, sparse, tensor)
#     165     """
#     166     if not batch_shape and tensor is None:
# --> 167         assert shape is not None, ('Please provide to Input either a `shape`'
#     168                                    ' or a `batch_shape` argument. Note that '
#     169                                    '`shape` does not include the batch '
#
# AssertionError: Please provide to Input either a `shape` or a `batch_shape` argument. Note that `shape` does not include the batch dimension.
